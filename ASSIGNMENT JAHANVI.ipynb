# %%
import requests

# Making a GET request
r = requests.get('https://www.bls.gov/')

# print request object
print(r.url)

# print status code
print(r.status_code)
# Out:
# https://www.bls.gov/
# 200

# %%
import requests
from bs4 import BeautifulSoup


# Making a GET request
r = requests.get('https://www.bls.gov/')

# check status code for response received
# success code - 200
print(r)

# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- P1 -->
#   <meta charset="utf-8"/>
#   <meta content="initial-scale=0.8; width=device-width" name="viewport">
#    <title>
#     U.S. Bureau of Labor Statistics
#    </title>
#    <!-- ****************************************** Begin META TAGS********************************************* -->
#    <link href="/stylesheets/bls_home.css" media="all" rel="Stylesheet" type="text/css"/>
#    <!-- START include/global/head.stm -->
#    <script id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=DOL&amp;subagency=BLS&amp;yt=true">
#    </script>
#    <script src="/javascripts/jquery-latest.js">
#    </script>
#    <script src="/javascripts/bls-latest.js">
#    </script>
#    <script src="/javascripts/jquery-tools.js">
#    </script>
#    <script src="/javascripts/jquery-migrate-1.2.1.min.js">
#    </script>
#    <link href="/assets/bootstrap/latest/bootstrap.min.css" rel="stylesheet"/>
#    <script src="/assets/bootstrap/latest/popper.min.js">
#    </script>
#    <script src="/assets/bootstrap/latest/bootstrap.min.js">
#    </script>
#    <link href="/stylesheets/bls_combined.css" rel="stylesheet" type="text/css"/>
#    <link href="/stylesheets/bls_content.css" rel="stylesheet" type="text/css"/>
#    <link href="/stylesheets/bls_tables.css" rel="stylesheet" type="text/css"/>
#    <link href="/stylesheets/jquery-tools.css" rel="stylesheet" type="text/css"/>
#    <link href="/stylesheets/bls_nr.css" rel="stylesheet" type="text/css"/>
#    <!--[if lt IE 9]>
# 		<link href="/stylesheets/ie8-styles.css" media="all" rel="Stylesheet" type="text/css">
# 	<![endif]-->
#    <!--[if lt IE 8]>
# 		<link href="/stylesheets/ie7-styles.css" media="all" rel="Stylesheet" type="text/css">
# 	<![endif]-->
#    <!--[if lt IE 7]>
# 		<link href="/stylesheets/ie6-styles.css" media="all" rel="Stylesheet" type="text/css">
# 		<style>
# 		body {
# 			behavior:url(/stylesheets/csshover2.htc);
# 		}
# 		</style>
# 	<![endif]-->
#    <!--[if IE]>
# 		<style>
# 		body {
# 			font-size: expression(1 / (screen.deviceXDPI / 96) * 84 + '%');
# 		}
# 		</style>
# 	<![endif]-->
#    <noscript>
#     <link href="/stylesheets/bls_noscript.css" rel="stylesheet" type="text/css"/>
#    </noscript>
#    <!--  This means that the browser will (probably) render the width of the page at the width of its own screen. -->
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <meta content="IE=Edge" http-equiv="x-ua-compatible">
#     <meta content="https://www.bls.gov/images/bls_emblem.png" property="og:image"/>
#     <style>
#      td.gsc-table-cell-thumbnail{
# 			display:none !important;
# 			}
#     </style>
#     <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180">
#      <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
#       <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png">
#        <link href="/manifest.json" rel="manifest">
#         <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon">
#          <meta content="#ffffff" name="theme-color"/>
#          <!-- END include/global/head.stm -->
#          <meta content="BLS" name="agency"/>
#          <meta content="general" name="audience"/>
#          <meta content="The Bureau of Labor Statistics is the principal fact-finding agency for the Federal Government in the broad field of labor economics and statistics." name="description"/>
#          <meta content="Employment statistics, US employment statistics, jobless rates, CPI, PPI, labor statistics, labor stats, unemployment data, employment figures, unemployment figures, consumer spending, consumer spending statistics, productivity, compensation, occupational outlook" name="keywords"/>
#          <link href="/feed/bls_latest.rss" rel="alternate" title="BLS Latest Numbers" type="application/rss+xml"/>
#          <!-- ****************************************** End META TAGS *********************************************** -->
#          <meta content="355233834527093" property="fb:page_id">
#           <meta content="https://www.bls.gov/images/bls_emblem.png" property="og:image">
#            <script>
#             $(document).ready(function(){$(".tooltip-homepage").tooltip({ position: "top center" ,effect: "fade", offset:[0,50]}).dynamic({ bottom: { direction: 'down'} });});function random_rotate(_min,_max,id,rel_url,stm){var TOTAL = (_max + 1) - _min;var f = Math.floor(Math.random()*(TOTAL))+ _min;f = f < 10 ? "00" + f : f < 100 ? "0" + f : f;f = rel_url+stm+f+".stm";if(window.ActiveXObject){xmlhttp=new ActiveXObject("Microsoft.XMLHTTP");}else if (window.XMLHttpRequest){xmlhttp=new XMLHttpRequest();}xmlhttp.open("GET",f,false);xmlhttp.send();if(xmlhttp.status==200){document.getElementById(id).innerHTML=xmlhttp.responseText;}}
#            </script>
#            <script>
#             $(document).ready(function(){
# var geoRand = Math.floor(Math.random()*8);
# $(".bootstrap.content-tab-panels .tab_link").eq(geoRand).addClass('active').parents('.content-tab-panels').find(".tab-content .tab-pane").eq(geoRand).addClass('active show');
# setTimeout(function(){
# $(".slideshow-item.cloned a").each(function(){
# $(this).attr("tabindex","-1")
# })
# $(".slideshow-item a").on("focus",function(){
# $(this).parents(".scrollable")[0].scrollLeft=0;
# $(".scrollable").data("scrollable").seekTo(Number($(this).parents(".items").find(".slideshow-item").index($(this).parents(".slideshow-item")))-1,0)
# })
# },1000)
# });
#            </script>
#           </meta>
#          </meta>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- ThreeColHead Begin -->
#   <!-- DOL BANNER BEGIN -->
#   <!-- DOL BANNER START -->
#   <header aria-label="global-header">
#    <!-- Header is closed at the end of BLS banner -->
#    <a class="skiplink" href="#startcontent">
#     Skip to Content
#    </a>
#    <div id="usa-banner-wrapper">
#     <div class="bootstrap standard-width" id="usa-banner">
#      <div class="content">
#       <div class="USA-flag-link">
#        <img alt="U.S. flag" src="https://www.dol.gov/themes/opa_theme/img/flag-favicon-57.png"/>
#        <p>
#         An official website of the United States government
#         <button aria-controls="usaBanner" aria-expanded="false" data-target="#usaBanner" data-toggle="collapse" type="button">
#          Here is how you know
#          <span class="oi" data-glyph="chevron-bottom">
#          </span>
#         </button>
#        </p>
#       </div>
#       <a class="dolHolder" href="https://www.dol.gov/" id="dolHolder" target="_blank">
#        <img alt="Department of Labor Logo" src="https://www.dol.gov/themes/opa_theme/img/logo-primary.svg">
#         United States Department of Labor
#        </img>
#       </a>
#      </div>
#      <div class="collapse" id="usaBanner">
#       <div class="row">
#        <div class="col-md-6">
#         <img alt="Dot gov" src="https://www.dol.gov/themes/opa_theme/img/icon-dot-gov.svg"/>
#         <p>
#          <strong>
#           The .gov means it's official.
#          </strong>
#          <br/>
#          Federal government websites often end in .gov or .mil. Before sharing sensitive information,
# 			make sure you're on a federal government site.
#         </p>
#        </div>
#        <div class="col-md-6">
#         <img alt="Https" class="usa-banner-icon usa-media_block-img" src="https://www.dol.gov/themes/opa_theme/img/icon-https.svg"/>
#         <p>
#          <strong>
#           The site is secure.
#          </strong>
#          <br/>
#          The
#          <strong>
#           https://
#          </strong>
#          ensures that you are connecting to the official website and that any
# 			information you provide is encrypted and transmitted securely.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- DOL BANNER END -->
#    <!-- DOL BANNER END -->
#    <!-- BLS BANNER BEGIN -->
#    <div id="bls-banner-wrapper">
#     <div id="top">
#     </div>
#     <div class="bootstrap standard-width">
#      <div>
#       <div class="row" id="bls-banner">
#        <div class="col-sm-12 col-md-7" id="bls-banner-emblem">
#         <a href="https://www.bls.gov/">
#          U.S. Bureau of Labor Statistics
#         </a>
#        </div>
#        <div class="col-sm-12 col-md-5 d-none d-md-block" id="bls-banner-right">
#         <div id="bls-banner-links">
#          <span class="social-follow">
#           <a aria-label="Follow Us on the Bureau of Labor Statistics Twitter" href="http://twitter.com/BLS_gov" target="_blank" title="Follow BLS on Twitter">
#            Follow Us
#           </a>
#          </span>
#          <span class="social-follow-links">
#           <!-- <img src="/images/icons/facebook.png"/>-->
#           <a aria-label="Bureau of Labor Statistics Twitter" href="http://twitter.com/BLS_gov" target="_blank">
#            <img alt="Follow BLS on Twitter" src="/images/icons/twitter.png" style="margin-top:-10px;"/>
#           </a>
#           <!--<img src="/images/icons/linkedin.png"/>-->
#          </span>
#          |
#          <a href="/schedule/news_release/">
#           Release Calendar
#          </a>
#          |
#          <a aria-label="Blog page" href="https://blogs.bls.gov/blog/">
#           Blog
#          </a>
#         </div>
#         <div class="bls-banner-search" id="bls-banner-search1">
#          <form action="/search/query" method="get">
#           <label class="invisible" for="bls-banner-search-submit1">
#            Search button
#           </label>
#           <input alt="BLS Search Submit" id="bls-banner-search-submit1" name="term" src="/images/buttons/search_button_blue_16.png" title="Submit" type="image"/>
#           <label class="invisible" for="bls-banner-search-input1">
#            Search:
#           </label>
#           <input id="bls-banner-search-input1" name="query" onclick="this.value=''; this.onclick = null;" title="Search Input" type="text" value="Search BLS.gov"/>
#          </form>
#         </div>
#        </div>
#        <div class="clearfloat">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <!-- Header is opened at the begining of DOL banner -->
#   <!-- BLS BANNER END -->
#   <!-- MAIN NAV BEGIN -->
#   <div id="main-nav-wrapper">
#    <div id="main-nav-container">
#     <div>
#      <div class="bootstrap standard-width">
#       <nav aria-label="top-level navigation menu" class="navbar navbar-expand-md">
#        <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation menu" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon">
#          Menu
#         </span>
#        </button>
#        <div class="collapse navbar-collapse" id="navbarSupportedContent">
#         <ul class="nojs navbar-nav mr-auto">
#          <li class="dropdownSearch">
#           <div class="dropdown-search" id="bls-banner-search">
#            <form action="/search/query" method="get">
#             <label class="invisible" for="bls-banner-search-submit">
#              Search button
#             </label>
#             <input alt="BLS Search Submit" id="bls-banner-search-submit" name="term" src="/images/buttons/search_button_blue_20.png" title="Submit" type="image"/>
#             <label class="invisible" for="bls-banner-search-input">
#              Search:
#             </label>
#             <input id="bls-banner-search-input" name="query" onclick="this.value=''; this.onclick = null;" title="Search Input" type="text" value="Search BLS.gov"/>
#            </form>
#           </div>
#          </li>
#          <li class="nav-item dropdown active">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://www.bls.gov/" id="navbarDropdown1" role="button">
#            Home
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown1" class="dropdown-menu">
#            <!-- ********************************************** Begin Home Tab LIST ****************************************** -->
#            <!-- 1st column -->
#            <div class="main-nav-submenu" id="submenu-home">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="About BLS" href="/bls/infohome.htm">
#                About BLS
#               </a>
#              </li>
#              <li>
#               <a aria-label="BLS History" href="/bls/history/home.htm">
#                History
#               </a>
#              </li>
#              <li>
#               <a aria-label="Our Leadership" href="/bls/senior_staff/home.htm">
#                Our Leadership
#               </a>
#              </li>
#              <li>
#               <a aria-label="Budget and Performance" href="/bls/bls_budget_and_performance.htm">
#                Budget and Performance
#               </a>
#              </li>
#              <li>
#               <a aria-label="Questions and Answers" href="/bls/faqs.htm">
#                Questions and Answers
#               </a>
#              </li>
#              <li>
#               <a aria-label="A-Z Index" href="/bls/topicsaz.htm">
#                A-Z Index
#               </a>
#              </li>
#              <li>
#               <a aria-label="Glossary" href="/bls/glossary.htm">
#                Glossary
#               </a>
#              </li>
#              <li>
#               <a aria-label="Careers at BLS" href="/jobs/">
#                Careers at BLS
#               </a>
#              </li>
#              <li>
#               <a aria-label="BLS Speakers Available" href="/bls/bls-speakers/">
#                BLS Speakers Available
#               </a>
#              </li>
#              <li>
#               <a aria-label="Errata" href="/errata/">
#                Errata
#               </a>
#              </li>
#              <li>
#               <a aria-label="Contact BLS" href="/bls/contact.htm">
#                Contact BLS
#               </a>
#              </li>
#             </ul>
#             <!-- 2nd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Overview of BLS Statistics" href="/bls/overview.htm">
#                Overview of BLS Statistics
#               </a>
#              </li>
#              <li>
#               <a aria-label="Demographics Data" href="/bls/demographics.htm">
#                Demographics
#               </a>
#              </li>
#              <li>
#               <a aria-label="Statistics by Industries" href="/bls/industry.htm">
#                Industries
#               </a>
#              </li>
#              <li>
#               <a aria-label="Statistics on Business Costs" href="/bls/business.htm">
#                Business Costs
#               </a>
#              </li>
#              <li>
#               <a aria-label="Statistics by Occupations" href="/bls/occupation.htm">
#                Occupations
#               </a>
#              </li>
#              <li>
#               <a aria-label="Statistics by Geography" href="/bls/geography.htm">
#                Geography
#               </a>
#              </li>
#             </ul>
#             <!-- 3rd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Resources For" href="/audience/">
#                Resources For
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Business Leaders" href="/audience/business.htm">
#                Business Leaders
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Consumers" href="/audience/consumers.htm">
#                Consumers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Developers site" href="/audience/developers.htm">
#                Developers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Economists or Economic Analyst" href="/audience/economists.htm">
#                Economists
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Financial Investors" href="/audience/investors.htm">
#                Investors
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Jobseekers" href="/audience/jobseekers.htm">
#                Jobseekers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Media" href="/audience/media.htm">
#                Media
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Public Policymakers" href="/audience/policy.htm">
#                Public Policymakers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Researcher" href="/audience/researcher.htm">
#                Researcher
#               </a>
#              </li>
#              <li>
#               <a aria-label="Resources for Students &amp; Teachers" href="/audience/students.htm">
#                Students &amp; Teachers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Survey Respondents" href="/respondents/">
#                Survey Respondents
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- ***********************************************End Home Tab LIST ******************************************** -->
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/bls/proghome.htm" id="navbarDropdown2" role="button">
#            Subjects
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown2" class="dropdown-menu">
#            <!-- ************************************* Begin SUBJECTS TAB list ****************************************** -->
#            <!-- 1st column -->
#            <div class="main-nav-submenu" id="submenu-programs">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Statistics on Inflation &amp; Prices" href="/bls/inflation.htm">
#                Inflation &amp; Prices
#               </a>
#              </li>
#              <li>
#               <a aria-label="Consumer Price Index " href="/cpi/">
#                Consumer Price Index
#               </a>
#              </li>
#              <li>
#               <a aria-label="Producer Price Indexes" href="/ppi/">
#                Producer Price Indexes
#               </a>
#              </li>
#              <li>
#               <a aria-label="Import/Export Price Indexes" href="/mxp/">
#                Import/Export Price Indexes
#               </a>
#              </li>
#              <li>
#               <a aria-label="Contract Escalation" href="/bls/escalation.htm">
#                Contract Escalation
#               </a>
#              </li>
#              <li>
#               <a aria-label="Price Index Research" href="/pir/">
#                Price Index Research
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Statistics on Pay &amp; Benefits" href="/bls/wages.htm">
#                Pay &amp; Benefits
#               </a>
#              </li>
#              <li>
#               <a aria-label="Employment Costs Trends" href="/ncs/ect/">
#                Employment Costs
#               </a>
#              </li>
#              <li>
#               <a aria-label="National Compensation Data" href="/ncs/">
#                National Compensation Data
#               </a>
#              </li>
#              <li>
#               <a aria-label="Wage Data by Occupation" href="/oes/">
#                Wage Data by Occupation
#               </a>
#              </li>
#              <li>
#               <a aria-label="Earnings by Demographics" href="/cps/earnings.htm#demographics">
#                Earnings by Demographics
#               </a>
#              </li>
#              <li>
#               <a aria-label="Earnings by Industry" href="/ces/">
#                Earnings by Industry
#               </a>
#              </li>
#              <li>
#               <a aria-label="County Wages" href="https://www.bls.gov/cew/">
#                County Wages
#               </a>
#              </li>
#              <!--full path is needed since they have a folder on the data server-->
#              <li>
#               <a aria-label="Employee Benefits Survey" href="/ncs/ebs/">
#                Benefits
#               </a>
#              </li>
#              <li>
#               <a aria-label="Modeled Wage Estimates" href="/mwe/">
#                Modeled Wage Estimates
#               </a>
#              </li>
#              <li>
#               <a aria-label="Compensation Research &amp; Program Development" href="/crp/">
#                Compensation Research
#               </a>
#              </li>
#              <li>
#               <a aria-label="Strikes &amp; Lockouts" href="/wsp/">
#                Strikes &amp; Lockouts
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Occupational Requirements Survey" href="/ors/">
#                Occupational Requirements
#               </a>
#              </li>
#             </ul>
#             <!-- 2nd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Statistics on Unemployment" href="/bls/unemployment.htm">
#                Unemployment
#               </a>
#              </li>
#              <li>
#               <a aria-label="National Unemployment Rate" href="/cps/">
#                National Unemployment Rate
#               </a>
#              </li>
#              <li>
#               <a aria-label="State &amp; Local Unemployment Rates" href="/lau/">
#                State &amp; Local Unemployment Rates
#               </a>
#              </li>
#              <li>
#               <a aria-label="Unemployment Research" href="/ers/">
#                Unemployment Research
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Statistics on Employment" href="/bls/employment.htm">
#                Employment
#               </a>
#              </li>
#              <li>
#               <a aria-label="National Employment Statistics" href="/ces/">
#                National Employment
#               </a>
#              </li>
#              <li>
#               <a aria-label="State &amp; Local Employment, Hours, and Earnings" href="/sae/">
#                State &amp; Local Employment
#               </a>
#              </li>
#              <li>
#               <a aria-label="County Employment" href="https://www.bls.gov/cew/">
#                County Employment
#               </a>
#              </li>
#              <!--full path is needed since they have a folder on the data server-->
#              <li>
#               <a aria-label="Worker Characteristics" href="/cps/">
#                Worker Characteristics
#               </a>
#              </li>
#              <li>
#               <a aria-label="American Indian Report" href="/air/">
#                American Indian Report
#               </a>
#              </li>
#              <li>
#               <a aria-label="Employment Projections" href="/emp/">
#                Employment Projections
#               </a>
#              </li>
#              <li>
#               <a aria-label="Job Openings &amp; Labor Turnover Survey" href="/jlt/">
#                Job Openings &amp; Labor Turnover Survey
#               </a>
#              </li>
#              <li>
#               <a aria-label="Business Response Survey" href="/brs/">
#                Business Response Survey
#               </a>
#              </li>
#              <li>
#               <a aria-label="Employment by Occupation" href="/oes/">
#                Employment by Occupation
#               </a>
#              </li>
#              <li>
#               <a aria-label="Work Experience Over Time" href="/nls/">
#                Work Experience Over Time
#               </a>
#              </li>
#              <li>
#               <a aria-label="Business Employment Dynamics" href="/bdm/">
#                Business Employment Dynamics
#               </a>
#              </li>
#              <li>
#               <a aria-label="Foreign Direct Investment" href="/fdi/">
#                Foreign Direct Investment
#               </a>
#              </li>
#              <li>
#               <a aria-label="Employment Research and Program Development" href="/ers/">
#                Employment Research
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Workplace Injuries, Illnesses, and Fatalities" href="/iif/">
#                Workplace Injuries
#               </a>
#              </li>
#             </ul>
#             <!-- 3rd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Productivity Statistics" href="/bls/productivity.htm">
#                Productivity
#               </a>
#              </li>
#              <li>
#               <a aria-label="Labor and Total Factor Productivity" href="/productivity/">
#                Labor and Total Factor Productivity
#               </a>
#              </li>
#              <li>
#               <a aria-label="Productivity Research and Program Development" href="/dpr/">
#                Productivity Research
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Statistics on Spending &amp; Time Use" href="/bls/spending.htm">
#                Spending &amp; Time Use
#               </a>
#              </li>
#              <li>
#               <a aria-label="Consumer Expenditures Surveys" href="/cex/">
#                Consumer Expenditures
#               </a>
#              </li>
#              <li>
#               <a aria-label="How Americans Spend Time Survey" href="/tus/">
#                How Americans Spend Time
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="International Data and Technical Cooperation" href="/bls/international.htm">
#                International
#               </a>
#              </li>
#              <li>
#               <a aria-label="International Technical Cooperation" href="/itc/">
#                International Technical Cooperation
#               </a>
#              </li>
#              <li>
#               <a aria-label="Import/Export Price Indexes" href="/mxp/">
#                Import/Export Price Indexes
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Geographic Information" href="/regions/">
#                Geographic Information
#               </a>
#              </li>
#              <li>
#               <a aria-label="New England (Boston) Information Office" href="/regions/new-england/">
#                New England (Boston)
#               </a>
#              </li>
#              <li>
#               <a aria-label="New York-New Jersey (NY City) Information Office" href="/regions/new-york-new-jersey/">
#                New York-New Jersey (NY City)
#               </a>
#              </li>
#              <li>
#               <a aria-label="Mid-Atlantic (Philadelphia) Information Office" href="/regions/mid-atlantic/">
#                Mid-Atlantic (Philadelphia)
#               </a>
#              </li>
#              <li>
#               <a aria-label="Southeast (Atlanta) Information Office" href="/regions/southeast/">
#                Southeast (Atlanta)
#               </a>
#              </li>
#              <li>
#               <a aria-label="Midwest (Chicago) Information Office" href="/regions/midwest/">
#                Midwest (Chicago)
#               </a>
#              </li>
#              <li>
#               <a aria-label="Southwest (Dallas) Information Office" href="/regions/southwest/">
#                Southwest (Dallas)
#               </a>
#              </li>
#              <li>
#               <a aria-label="Mountain-Plains (Kansas City) Information Office" href="/regions/mountain-plains/">
#                Mountain-Plains (Kansas City)
#               </a>
#              </li>
#              <li>
#               <a aria-label="West (San Francisco) Information Office" href="/regions/west/">
#                West (San Francisco)
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- **************************************End SUBJECT AREAS ******************************************** -->
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/data/" id="navbarDropdown3" role="button">
#            Data Tools
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown3" class="dropdown-menu">
#            <!-- ******************************************** Begin DATA TOOLS LIST ****************************************** -->
#            <div class="main-nav-submenu" id="submenu-data">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Data Retrieval Tools Databases, Tables &amp; Calculators by Subject" href="/data/tools.htm">
#                Data Retrieval Tools
#               </a>
#              </li>
#              <li>
#               <a aria-label="BLS Popular Series Top Picks" href="https://data.bls.gov/cgi-bin/surveymost?bls">
#                BLS Popular Series
#               </a>
#              </li>
#              <li>
#               <a aria-label="Series Report" href="https://data.bls.gov/cgi-bin/srgate">
#                Series Report
#               </a>
#              </li>
#              <li>
#               <a aria-label="Top Picks, One Screen, Multi-Screen, and Maps" href="/data/home.htm">
#                Top Picks, One Screen, Multi-Screen, and Maps
#               </a>
#              </li>
#              <li>
#               <a aria-label="Data Finder" href="https://beta.bls.gov/dataQuery/search">
#                Data Finder
#               </a>
#              </li>
#              <li>
#               <a aria-label="Public Data API Programming Interface" href="/developers/home.htm">
#                Public Data API
#               </a>
#              </li>
#             </ul>
#             <!-- 2nd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Charts and Applications" href="/data/apps.htm">
#                Charts and Applications
#               </a>
#              </li>
#              <li>
#               <a aria-label="Charts for Economic News Releases" href="/charts/home.htm">
#                Charts for Economic News Releases
#               </a>
#              </li>
#              <li>
#               <a aria-label="CPI Inflation Calculator" href="/data/inflation_calculator.htm">
#                CPI Inflation Calculator
#               </a>
#              </li>
#              <li>
#               <a aria-label="Injury and Illness Calculator" href="https://data.bls.gov/iirc/">
#                Injury and Illness Calculator
#               </a>
#              </li>
#              <li>
#               <a aria-label="Pay Measure Comparison" href="https://data.bls.gov/apps/compensation-comparison-matrix/home.htm">
#                Pay Measure Comparison
#               </a>
#              </li>
#              <li>
#               <a aria-label="Demographic Data Sources" href="https://data.bls.gov/apps/demographic-comparison-matrix/home.htm">
#                Demographic Data Sources
#               </a>
#              </li>
#              <li>
#               <a aria-label="COVID-19 Economic Trends" href="https://data.bls.gov/apps/covid-dashboard/home.htm">
#                COVID-19 Economic Trends
#               </a>
#              </li>
#              <li>
#               <a aria-label="Industry Productivity Viewer" href="https://data.bls.gov/apps/industry-productivity-viewer/home.htm">
#                Industry Productivity Viewer
#               </a>
#              </li>
#              <li>
#               <a aria-label="Employment and Wages Data Viewer" href="https://data.bls.gov/cew/apps/data_views/data_views.htm#tab=Tables">
#                Employment and Wages Data Viewer
#               </a>
#              </li>
#              <li>
#               <a aria-label="Industry Finder from the Quarterly Census of Employment and Wages" href="https://data.bls.gov/cew/apps/bls_naics/bls_naics_app.htm">
#                Industry Finder from the Quarterly Census of Employment and Wages
#               </a>
#              </li>
#             </ul>
#             <!-- 3rd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Customized Tables" href="/data/tables.htm">
#                Customized Tables
#               </a>
#              </li>
#              <li>
#               <a aria-label="U.S. Economy at a Glance" href="/eag/eag.us.htm">
#                U.S. Economy at a Glance
#               </a>
#              </li>
#              <li>
#               <a aria-label="Regions, States &amp; Areas at a Glance" href="/eag/home.htm">
#                Regions, States &amp; Areas at a Glance
#               </a>
#              </li>
#              <li>
#               <a aria-label="Industry at a Glance" href="/iag/home.htm">
#                Industry at a Glance
#               </a>
#              </li>
#              <li>
#               <a aria-label="Text Files" href="https://download.bls.gov/pub/time.series/">
#                Text Files
#               </a>
#              </li>
#              <li>
#               <a aria-label="Historical News Release Tables" href="/data/#historical-tables">
#                News Release Tables
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="More Sources of Data" href="/bls/moredata.htm">
#                More Sources of Data
#               </a>
#              </li>
#              <li>
#               <a aria-label="Bureau of Labor Statistics Restricted Data Access" href="/rda/home.htm">
#                Restricted Data Access
#               </a>
#              </li>
#              <li>
#               <a aria-label="Discontinued Databases" href="/data/archived.htm">
#                Discontinued Databases
#               </a>
#              </li>
#              <li>
#               <a aria-label="Questions &amp; Answers regarding Bureau of Labor Statistics website data retrieval tools" href="/help/hlpform1.htm">
#                Questions &amp; Answers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Special Notices" href="/help/notice.htm">
#                Special Notices
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- *********************************************End DATABASES and TOOLS LIST ******************************************** -->
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/opub/" id="navbarDropdown4" role="button">
#            Publications
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown4" class="dropdown-menu">
#            <!-- ********************************************** Begin PUBLICATIONS LIST ****************************************** -->
#            <div class="main-nav-submenu" id="submenu-pubs">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Latest Publications" href="/opub/">
#                Latest Publications
#               </a>
#              </li>
#              <li>
#               <a aria-label="The Economics Daily" href="/opub/ted/">
#                The Economics Daily
#               </a>
#              </li>
#              <li>
#               <a aria-label="Monthly Labor Review" href="/opub/mlr/">
#                Monthly Labor Review
#               </a>
#              </li>
#              <li>
#               <a aria-label="Beyond the Numbers" href="/opub/btn/">
#                Beyond the Numbers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Spotlight on Statistics" href="/spotlight/">
#                Spotlight on Statistics
#               </a>
#              </li>
#              <li>
#               <a aria-label="Bureau of Labor Statistics Reports" href="/opub/reports">
#                Reports
#               </a>
#              </li>
#              <li>
#               <a aria-label="Commissioner's Corner" href="https://blogs.bls.gov/blog/">
#                Commissioner's Corner
#               </a>
#              </li>
#              <li>
#               <a aria-label="Videos" href="/video/">
#                Videos
#               </a>
#              </li>
#              <li>
#               <a aria-label="Career Outlook" href="/careeroutlook/">
#                Career Outlook
#               </a>
#              </li>
#             </ul>
#             <!-- 2nd column -->
#             <ul class="main-nav-submenu-inn">
#              <li>
#               <a aria-label="Occupational Outlook Handbook" href="/ooh/">
#                Occupational Outlook Handbook
#               </a>
#              </li>
#              <li>
#               <a aria-label="Geographic Profile" href="/opub/geographic-profile/">
#                Geographic Profile
#               </a>
#              </li>
#              <li>
#               <a aria-label="Handbook of Methods" href="/opub/hom/">
#                Handbook of Methods
#               </a>
#              </li>
#              <li>
#               <a aria-label="Research Papers - Office of Survey Methods Research" href="/osmr/research-papers/">
#                Research Papers
#               </a>
#              </li>
#              <li>
#               <a aria-label="Copyright Information" href="/opub/copyright-information.htm">
#                Copyright Information
#               </a>
#              </li>
#              <li>
#               <a aria-label="Contact &amp; Help" href="/opub/opbinfo.htm">
#                Contact &amp; Help
#               </a>
#              </li>
#              <li>
#               <a aria-label="Weekly Update" href="/opub/update.htm">
#                Weekly Update
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- ***********************************************End PUBLICATIONS LIST ******************************************** -->
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/bls/newsrels.htm" id="navbarDropdown5" role="button">
#            Economic Releases
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown5" class="dropdown-menu">
#            <!-- ********************************************** Begin ECONOMIC RELEASES LIST ****************************************** -->
#            <!-- 1st column -->
#            <div class="main-nav-submenu" id="submenu-news">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Latest Releases" href="/bls/newsrels.htm#latest-releases">
#                Latest Releases
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Major Economic Indicators" href="/bls/newsrels.htm#major">
#                Major Economic Indicators
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Schedules for news Releases" href="/schedule/news_release/">
#                Schedules for news Releases
#               </a>
#              </li>
#              <li>
#               <a aria-label="Release Calendar By Month" href="/schedule/">
#                By Month
#               </a>
#              </li>
#              <li>
#               <a aria-label="Release Calendar By News Release" href="/schedule/schedule/by_prog/all_sched.htm">
#                By News Release
#               </a>
#              </li>
#              <li>
#               <a aria-label="Release Calendar Current Year" href="/schedule/news_release/current_year.asp">
#                Current Year
#               </a>
#              </li>
#              <li>
#               <a aria-label="Schedules for Selected Bureau of Labor Statistics Economic News Releases for Prior Years" href="/bls/archived_sched.htm">
#                Prior Years
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Archived News Releases" href="/bls/news-release/">
#                Archived News Releases
#               </a>
#              </li>
#             </ul>
#             <!-- 2nd column -->
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Employment &amp; Unemployment" href="/bls/newsrels.htm#OEUS">
#                Employment &amp; Unemployment
#               </a>
#              </li>
#              <li>
#               <a aria-label="Monthly" href="/bls/newsrels.htm#OEUS">
#                Monthly
#               </a>
#              </li>
#              <li>
#               <a aria-label="Quarterly, annual, and other" href="/bls/newsrels.htm#OEUS">
#                Quarterly, annual, and other
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Inflation &amp; Prices" href="/bls/newsrels.htm#OPLC">
#                Inflation &amp; Prices
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Pay &amp; Benefits &amp; Workplace Injuries" href="/bls/newsrels.htm#OCWC">
#                Pay &amp; Benefits &amp; Workplace Injuries
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Productivity &amp; Technology" href="/bls/newsrels.htm#OPT">
#                Productivity &amp; Technology
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Employment Projections" href="/bls/newsrels.htm#OEP">
#                Employment Projections
#               </a>
#              </li>
#              <li class="heading">
#               <a aria-label="Regional News Releases" href="/bls/newsrels.htm#NEWS">
#                Regional News Releases
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="/k12/" id="navbarDropdown6" role="button">
#            Classroom
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown6" class="dropdown-menu">
#            <!-- ********************************************** Begin Students Tab LIST ****************************************** -->
#            <div class="main-nav-submenu" id="submenu-students">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="K-12 Student &amp; Teacher Resources" href="/k12/">
#                K-12 Student &amp; Teacher Resources
#               </a>
#              </li>
#              <li>
#               <a aria-label="Games &amp; Quizzes" href="/k12/games/">
#                Games &amp; Quizzes
#               </a>
#              </li>
#              <li>
#               <a aria-label="Student's Desk" href="/k12/students/">
#                Student's Desk
#               </a>
#              </li>
#              <li>
#               <a aria-label="Teacher's Desk" href="/k12/teachers/">
#                Teacher's Desk
#               </a>
#              </li>
#              <li>
#               <a aria-label="Questions &amp; Answers" href="/k12/faq.htm">
#                Questions &amp; Answers
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- ***********************************************End Students Tab LIST ******************************************** -->
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="https://beta.bls.gov" id="navbarDropdown7" role="button">
#            Beta
#            <span class="circle-arrow">
#            </span>
#           </a>
#           <div aria-labelledby="navbarDropdown7" class="dropdown-menu">
#            <!-- ***********************************************Start BETA LIST ******************************************** -->
#            <div class="main-nav-submenu" id="submenu-beta">
#             <ul class="main-nav-submenu-inn">
#              <li class="heading">
#               <a aria-label="Redesigned News Releases" href="https://beta.bls.gov/labs/?p=600">
#                Redesigned News Releases
#               </a>
#              </li>
#             </ul>
#            </div>
#            <!-- ***********************************************End BETA LIST ******************************************** -->
#           </div>
#          </li>
#         </ul>
#        </div>
#       </nav>
#      </div>
#     </div>
#     <div class="clearfloat">
#     </div>
#    </div>
#   </div>
#   <!-- MAIN NAV END -->
#   <!-- WRAPPER TOP BEGIN -->
#   <div id="wrapper-outer" role="main">
#    <div id="wrapper">
#     <div id="container">
#      <!-- WRAPPER TOP END -->
#      <div class="clearfloat" id="startcontent">
#      </div>
#      <h1 class="invisible">
#       U.S. Bureau of Labor Statistics Home
#      </h1>
#      <h2 class="invisible">
#       Homepage Sections
#      </h2>
#      <div id="homepage">
#       <div id="left-side-content">
#        <!-- Place announcements here -->
#        <!-- End announcements here -->
#        <div id="news-releases">
#         <div class="clearfloat">
#         </div>
#         <!-- BEGIN 1 NEWS RELEASE ABSTRACT-->
#         <div class="nr-calendar-date">
#          <div class="nr-date-month">
#           Dec
#          </div>
#          <div class="nr-date-day">
#           14
#          </div>
#         </div>
#         <div class="nr-entry">
#          <span class="heading">
#           <a href="/news.release/ximpim.nr0.htm" title="U.S. import prices decline 0.6% in November; export prices fall 0.3%">
#            U.S. import prices decline 0.6% in November; export prices fall 0.3%
#           </a>
#          </span>
#          <p>
#           Prices for U.S. imports decreased 0.6 percent in November, after declining 0.4 percent in
# October. Export prices fell 0.3 percent in November following a 0.4-percent drop the
# previous month. Over the past year, import prices increased 2.7 percent and export prices
# rose 6.3 percent.
#          </p>
#          <p>
#           <a class="blue-links" href="/news.release/ximpim.nr0.htm" title="HTML version of U.S. Import and Export Price Indexes News Release">
#            HTML
#           </a>
#           |
#           <a class="blue-links" href="/news.release/pdf/ximpim.pdf" title="PDF version of U.S. Import and Export Price Indexes News Release">
#            PDF
#           </a>
#           |
#           <a class="blue-links" href="/feed/ximpim.rss" title="Subscribe to the U.S. Import and Export Price Indexes News Release Feed">
#            RSS
#           </a>
#           |
#           <a class="blue-links" href="/charts/import-export/" title="Charts related to the latest U.S. Import and Export Price Indexes News Release">
#            Charts
#           </a>
#          </p>
#         </div>
#         <!-- END 1 NEWS RELEASE ABSTRACT-->
#         <div class="clearfloat">
#         </div>
#         <div id="nr-archive">
#          <!-- BEGIN 2 NEWS RELEASE ARCHIVE LIST-->
#          <span class="nr-archive-date">
#           12/13/2022
#          </span>
#          <span class="heading">
#           <a href="/news.release/cpi.nr0.htm" title="CPI for all items rises 0.1% in November as shelter and food increase">
#            CPI for all items rises 0.1% in November as shelter and food increase
#           </a>
#          </span>
#          <div class="clearfloat">
#          </div>
#          <!-- END 2 NEWS RELEASE ARCHIVE LIST-->
#          <!-- BEGIN 3 NEWS RELEASE ARCHIVE LIST-->
#          <span class="nr-archive-date">
#           12/13/2022
#          </span>
#          <span class="heading">
# ...
#          </a>
#          <br/>
#          <span class="data" title="Compensation, all civilian workers, quarterly percent change, seasonally adjusted">
#           +1.2%   in 3rd Qtr of 2022
#          </span>
#          <a aria-label="News Release for  Employment Cost Index (ECI): Compensation, all civilian workers, quarterly percent change, seasonally adjusted" href="/news.release/eci.toc.htm">
#           <img alt="News Release" src="/images/icons/icon_new_release_small.gif"/>
#          </a>
#          <a aria-label="Historical Data for  Employment Cost Index (ECI): Compensation, all civilian workers, quarterly percent change, seasonally adjusted" href="/pdq/SurveyOutputServlet?data_tool=latest_numbers&amp;series_id=CIS1010000000000Q">
#           <img alt="Historical Data" src="/images/layout/historical_icon.gif" title="10-years of historical data"/>
#          </a>
#         </p>
#         <p>
#          <a href="/news.release/prod2.toc.htm">
#           Productivity:
#          </a>
#          <br/>
#          <span class="data" title="Output per hour, nonfarm business, percent change from previous quarter at annual rate, seasonally adjusted">
#           +0.8%(r)   in 3rd Qtr of 2022
#          </span>
#          <a aria-label="News Release for  Productivity: Output per hour, nonfarm business, percent change from previous quarter at annual rate, seasonally adjusted" href="/news.release/prod2.toc.htm">
#           <img alt="News Release" src="/images/icons/icon_new_release_small.gif"/>
#          </a>
#          <a aria-label="Historical Data for  Productivity: Output per hour, nonfarm business, percent change from previous quarter at annual rate, seasonally adjusted" href="/pdq/SurveyOutputServlet?data_tool=latest_numbers&amp;series_id=PRS85006092">
#           <img alt="Historical Data" src="/images/layout/historical_icon.gif" title="10-years of historical data"/>
#          </a>
#         </p>
#         <p>
#          <a href="/news.release/ximpim.toc.htm">
#           U.S. Import Price Index:
#          </a>
#          <br/>
#          <span class="data" title="All imports, 1-month percent change, not seasonally adjusted">
#           -0.6%   in Nov 2022
#          </span>
#          <a aria-label="News Release for  U.S. Import Price Index: All imports, 1-month percent change, not seasonally adjusted" href="/news.release/ximpim.toc.htm">
#           <img alt="News Release" src="/images/icons/icon_new_release_small.gif"/>
#          </a>
#          <a aria-label="Historical Data for  U.S. Import Price Index: All imports, 1-month percent change, not seasonally adjusted" href="/pdq/SurveyOutputServlet?data_tool=latest_numbers&amp;series_id=EIUIR&amp;output_view=pct_1mth">
#           <img alt="Historical Data" src="/images/layout/historical_icon.gif" title="10-years of historical data"/>
#          </a>
#         </p>
#         <p>
#          <a href="/news.release/ximpim.toc.htm">
#           U.S. Export Price Index:
#          </a>
#          <br/>
#          <span class="data" title="All exports, 1-month percent change, not seasonally adjusted">
#           -0.3%   in Nov 2022
#          </span>
#          <a aria-label="News Release for  U.S. Export Price Index: All exports, 1-month percent change, not seasonally adjusted" href="/news.release/ximpim.toc.htm">
#           <img alt="News Release" src="/images/icons/icon_new_release_small.gif"/>
#          </a>
#          <a aria-label="Historical Data for  U.S. Export Price Index: All exports, 1-month percent change, not seasonally adjusted" href="/pdq/SurveyOutputServlet?data_tool=latest_numbers&amp;series_id=EIUIQ&amp;output_view=pct_1mth">
#           <img alt="Historical Data" src="/images/layout/historical_icon.gif" title="10-years of historical data"/>
#          </a>
#         </p>
#         <div id="sidebar-explainers">
#          <span>
#           <img alt="Historical Data" src="/images/icons/explainers_historical_data.gif"/>
#           Historical Data
#          </span>
#          <span>
#           <img alt="News Release" src="/images/icons/explainers_news_release.gif"/>
#           News Release
#          </span>
#          <span>
#           p - preliminary
#          </span>
#         </div>
#        </div>
#        <!-- ALL VARIABLES
# 			Errors: 	Config: 	Data: 	-->
#       </div>
#       <!-- **************************************** End SIDEBAR CONTENT ***************************************** -->
#      </div>
#      <div class="clearfloat">
#      </div>
#      <div class="social-media">
#       <div>
#        Recommend this page using:
#       </div>
#       <div>
#        <a class="share_facebook" href="javascript:void(0);">
#         <img alt="share on facebook" src="/images/icons/facebook.png"/>
#        </a>
#        <span>
#         <a class="share_facebook" href="javascript:void(0);">
#          Facebook
#         </a>
#        </span>
#       </div>
#       <div>
#        <a class="share_twitter" href="javascript:void(0);">
#         <img alt="share on twitter" src="/images/icons/twitter.png"/>
#        </a>
#        <span>
#         <a class="share_twitter" href="javascript:void(0);">
#          Twitter
#         </a>
#        </span>
#       </div>
#       <div>
#        <a class="share_linkedin" href="javascript:void(0);">
#         <img alt="share on linkedin" src="/images/icons/linkedin.png"/>
#        </a>
#        <span>
#         <a class="share_linkedin" href="javascript:void(0);">
#          LinkedIn
#         </a>
#        </span>
#       </div>
#       <!--<div><a href="javascript:void(0);" class="share_googleplus"><img src="/images/icons/google.png"></a><span><a href="javascript:void(0);" class="share_googleplus">Google+</a></span></div>-->
#      </div>
#      <!-- WRAPPER BOTTOM BEGIN -->
#     </div>
#     <!-- close id="wrapper-outer" -->
#    </div>
#    <!-- close id="wrapper" -->
#   </div>
#   <!-- close id="container" -->
#   <!-- WRAPPER BOTTOM END -->
#   <!-- FOOTER LEFT BEGIN -->
#   <footer aria-label="global-footer">
#    <!-- Footer Nav Menu-->
#    <div class="footerNav">
#     <ul class="footerNavInner">
#      <li class="footerNavItem">
#       <a href="https://www.bls.gov/">
#        Home
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="/bls/proghome.htm">
#        Subjects
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="/data/">
#        Data Tools
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="/opub/">
#        Publications
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="/bls/newsrels.htm">
#        Economic Releases
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="/k12/">
#        Classroom
#       </a>
#      </li>
#      <li class="footerNavItem">
#       <a href="https://beta.bls.gov">
#        Beta
#       </a>
#      </li>
#     </ul>
#    </div>
#    <!-- Footer Nav Menu-->
#    <script>
#     /*<![CDATA[*/(function(){var sz = document.createElement('script'); sz.type = 'text/javascript'; sz.async = true;sz.src = '//siteimproveanalytics.com/js/siteanalyze_6032860.js';var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sz, s);})();/*]]>*/
#    </script>
#    <div id="footer-primary-wrapper">
#     <div class="bootstrap standard-width">
#      <div class="row" id="footer-container">
#       <div class="col-xs-12 col-sm-12 col-md-4 col-lg-4" id="footer-links-container">
#        <div class="bls-lftside-holder">
#         <div class="bls-logo-footer">
#          <img alt="U.S. Bureau of Labor Statistics Logo " class="responsiveImg" src="/images/bls_emblem_trans.png">
#           <div class="d-none d-md-block clearfloat">
#            <br/>
#            <br/>
#           </div>
#          </img>
#         </div>
#         <div class="address-contact-footer">
#          <!-- FOOTER LEFT END -->
#          <address class="footer-address">
#           <strong>
#            U.S. Bureau of Labor Statistics
#           </strong>
#           <span>
#            Postal Square Building
#           </span>
#           <span>
#            2 Massachusetts Avenue NE
#           </span>
#           <span>
#            Washington, DC 20212-0001
#           </span>
#          </address>
#          <!-- FOOTER CENTER BEGIN -->
#          <!-- FOOTER CENTER END -->
#          <span class="footer-contact">
#           <a aria-label="Telephone: 1-202-691-5200" class="number" href="tel:12026915200">
#            <span>
#             Telephone:
#            </span>
#            <span>
#             1-202-691-5200
#            </span>
#           </a>
#           <a aria-label="If you are deaf, hard of hearing, or have a speech disability, please dial 7-1-1 to access telecommunications relay services" class="number" href="tel:711">
#            <span>
#             Telecommunications Relay Service:
#            </span>
#            <span>
#             7-1-1
#            </span>
#           </a>
#           <a aria-label="www.bls.gov" href="/home.htm">
#            www.bls.gov
#           </a>
#           <a aria-label="Contact Us" href="https://data.bls.gov/forms/opb.htm?/home.htm">
#            Contact Us
#           </a>
#          </span>
#          <!-- FOOTER RIGHT BEGIN -->
#         </div>
#        </div>
#       </div>
#       <div class="row col-xs-12 col-sm-12 col-md-8 col-lg-8" id="quicklinks">
#        <div class="col-xs-6 col-sm-6 col-md-6 col-lg-5">
#         <strong>
#          resources
#         </strong>
#         <a aria-controls="quicklinksli5" aria-expanded="false" aria-label="resources Sub Menu" class="d-sm-none" data-toggle="collapse" href="#quicklinksli5" role="button">
#         </a>
#         <div class="collapse" id="quicklinksli5">
#          <ul class="d-sm-block">
#           <li>
#            <a aria-label="Office of Inspector General (OIG) website" href="https://www.oig.dol.gov/">
#             Inspector General (OIG)
#            </a>
#           </li>
#           <li>
#            <a aria-label="Budget and Performance" href="/bls/bls_budget_and_performance.htm">
#             Budget and Performance
#            </a>
#           </li>
#           <li>
#            <a aria-label="Department of Labor Grants" href="https://www.dol.gov/grants">
#             Department of Labor Grants
#            </a>
#           </li>
#           <li>
#            <a aria-label="No Fear Act" href="/bls/no_fear_act.htm">
#             No Fear Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="USA.gov website" href="https://www.usa.gov/">
#             USA.gov
#            </a>
#           </li>
#           <li>
#            <a aria-label="Register to vote at Vote.gov" href="https://www.vote.gov/" title="Public and private decision making about worker rights and benefits depend on you exercising your fundamental right. Register to vote at Vote.gov!">
#             Vote.gov
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-xs-6 col-sm-6 col-md-6 col-lg-5">
#         <strong>
#          about the site
#         </strong>
#         <a aria-controls="quicklinksli6" aria-expanded="false" aria-label="about this site Sub Menu" class="d-sm-none" data-toggle="collapse" href="#quicklinksli6" role="button">
#         </a>
#         <div class="collapse" id="quicklinksli6">
#          <ul class="d-sm-block">
#           <li>
#            <a aria-label="Sitemap" href="/bls/sitemap.htm">
#             Sitemap
#            </a>
#           </li>
#           <li>
#            <a aria-label="Freedom of Information Act" href="/bls/blsfoia.htm">
#             Freedom of Information Act
#            </a>
#           </li>
#           <li>
#            <a aria-label="Privacy and Security Statement" href="/bls/pss.htm">
#             Privacy and Security Statement
#            </a>
#           </li>
#           <li>
#            <a aria-label="Disclaimers" href="/bls/disclaimer.htm">
#             Disclaimers
#            </a>
#           </li>
#           <li>
#            <a aria-label="Linking and Copyright Information" href="/bls/linksite.htm">
#             Linking and Copyright Info
#            </a>
#           </li>
#           <li>
#            <a aria-label="Important Website Notices" href="/bls/website-policies.htm">
#             Important Website Notices
#            </a>
#           </li>
#           <li>
#            <a aria-label="Help and Tutorials" href="/help/">
#             Help and Tutorials
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="footer-secondary-wrapper">
#     <div class="bootstrap standard-width">
#      <div>
#       <span>
#        Connect With BLS
#       </span>
#       <div class="social-media-icons">
#        <a class="social-media-icon" href="http://twitter.com/BLS_gov" rel="noopener noreferrer" target="_blank" title="BLS Twitter">
#         <!--?xml version="1.0" encoding="utf-8"?-->
#         <svg aria-hidden="true" class="svg-inline--fa fa-twitter fa-w-16" data-icon="twitter" data-prefix="fab" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#          <path d="M459.37 151.716c.325 4.548.325 9.097.325 13.645 0 138.72-105.583 298.558-298.558 298.558-59.452 0-114.68-17.219-161.137-47.106 8.447.974 16.568 1.299 25.34 1.299 49.055 0 94.213-16.568 130.274-44.832-46.132-.975-84.792-31.188-98.112-72.772 6.498.974 12.995 1.624 19.818 1.624 9.421 0 18.843-1.3 27.614-3.573-48.081-9.747-84.143-51.98-84.143-102.985v-1.299c13.969 7.797 30.214 12.67 47.431 13.319-28.264-18.843-46.781-51.005-46.781-87.391 0-19.492 5.197-37.36 14.294-52.954 51.655 63.675 129.3 105.258 216.365 109.807-1.624-7.797-2.599-15.918-2.599-24.04 0-57.828 46.782-104.934 104.934-104.934 30.213 0 57.502 12.67 76.67 33.137 23.715-4.548 46.456-13.32 66.599-25.34-7.798 24.366-24.366 44.833-46.132 57.827 21.117-2.273 41.584-8.122 60.426-16.243-14.292 20.791-32.161 39.308-52.628 54.253z" fill="currentColor">
#          </path>
#         </svg>
#         <span class="sr-only">
#          Twitter
#         </span>
#        </a>
#        <a class="social-media-icon" href="https://www.youtube.com/channel/UCijn3WBpHtx4AvSya7NER9Q" rel="noopener noreferrer" target="_blank" title="BLS Youtube">
#         <!--?xml version="1.0" encoding="utf-8"?-->
#         <svg aria-hidden="true" class="svg-inline--fa fa-youtube fa-w-18" data-icon="youtube" data-prefix="fab" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg">
#          <path d="M549.655 124.083c-6.281-23.65-24.787-42.276-48.284-48.597C458.781 64 288 64 288 64S117.22 64 74.629 75.486c-23.497 6.322-42.003 24.947-48.284 48.597-11.412 42.867-11.412 132.305-11.412 132.305s0 89.438 11.412 132.305c6.281 23.65 24.787 41.5 48.284 47.821C117.22 448 288 448 288 448s170.78 0 213.371-11.486c23.497-6.321 42.003-24.171 48.284-47.821 11.412-42.867 11.412-132.305 11.412-132.305s0-89.438-11.412-132.305zm-317.51 213.508V175.185l142.739 81.205-142.739 81.201z" fill="currentColor">
#          </path>
#         </svg>
#         <span class="sr-only">
#          Youtube
#         </span>
#        </a>
#        <a class="social-media-icon" href="javascript:window.open('https://public.govdelivery.com/accounts/USDOLBLS/subscriber/new ','Popup','width=800,height=500,toolbar=no,scrollbars=yes,resizable=yes'); void('');" id="email" onclick="window.status='Subscribe'; return true" onmouseout="window.status=''; return true" onmouseover="window.status='Subscribe'; return true" title="Subscribe to BLS E-mail Updates">
#         <!--?xml version="1.0" encoding="utf-8"?-->
#         <svg aria-hidden="true" class="svg-inline--fa fa-envelope fa-w-16" data-icon="envelope" data-prefix="fas" focusable="false" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#          <path d="M502.3 190.8c3.9-3.1 9.7-.2 9.7 4.7V400c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V195.6c0-5 5.7-7.8 9.7-4.7 22.4 17.4 52.1 39.5 154.1 113.6 21.1 15.4 56.7 47.8 92.2 47.6 35.7.3 72-32.8 92.3-47.6 102-74.1 131.6-96.3 154-113.7zM256 320c23.2.4 56.6-29.2 73.4-41.4 132.7-96.3 142.8-104.7 173.4-128.7 5.8-4.5 9.2-11.5 9.2-18.9v-19c0-26.5-21.5-48-48-48H48C21.5 64 0 85.5 0 112v19c0 7.4 3.4 14.3 9.2 18.9 30.6 23.9 40.7 32.4 173.4 128.7 16.8 12.2 50.2 41.8 73.4 41.4z" fill="currentColor">
#          </path>
#         </svg>
#         <span class="sr-only">
#          Email
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- FOOTER RIGHT END -->
#   <!-- ThreeColFoot End -->
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup


# Making a GET request
r = requests.get('https://www.bls.gov/')

# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')

# Getting the title tag
print(soup.title)

# Getting the name of the tag
print(soup.title.name)

# Getting the name of parent tag
print(soup.title.parent.name)

# use the child attribute to get
# the name of the child tag
# Out:
# <title>U.S. Bureau of Labor Statistics</title>
# title
# meta

# %%
import requests
from bs4 import BeautifulSoup


# Making a GET request
r = requests.get('https://www.bls.gov/')

# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')

images_list = []

images = soup.select('img')
for image in images:
	src = image.get('src')
	alt = image.get('alt')
	images_list.append({"src": src, "alt": alt})
	
for image in images_list:
	print(image)
# Out:
# {'src': 'https://www.dol.gov/themes/opa_theme/img/flag-favicon-57.png', 'alt': 'U.S. flag'}
# {'src': 'https://www.dol.gov/themes/opa_theme/img/logo-primary.svg', 'alt': 'Department of Labor Logo'}
# {'src': 'https://www.dol.gov/themes/opa_theme/img/icon-dot-gov.svg', 'alt': 'Dot gov'}
# {'src': 'https://www.dol.gov/themes/opa_theme/img/icon-https.svg', 'alt': 'Https'}
# {'src': '/images/icons/twitter.png', 'alt': 'Follow BLS on Twitter'}
# {'src': '/images/layout/homepage/boston.jpg', 'alt': 'boston'}
# {'src': '/images/layout/homepage/newyork.jpg', 'alt': 'newyork'}
# {'src': '/images/layout/homepage/philadelphia.jpg', 'alt': 'philadelphia'}
# {'src': '/images/layout/homepage/atlanta.jpg', 'alt': 'atlanta'}
# {'src': '/images/layout/homepage/chicago.jpg', 'alt': 'chicago'}
# {'src': '/images/layout/homepage/dallas.jpg', 'alt': 'dallas'}
# {'src': '/images/layout/homepage/kansascity.jpg', 'alt': 'kansascity'}
# {'src': '/images/layout/homepage/sanfrancisco.jpg', 'alt': 'sanfrancisco'}
# {'src': '/ooh/content/ooh_publication.png', 'alt': 'Occupational Outlook Handbook'}
# {'src': '/ooh/content/ooh-h-banner.png', 'alt': 'Occupational Outlook Handbook'}
# {'src': '/home/feature/2022-12-14-inflation-experiences-for-lower-and-higher-income-households.PNG', 'alt': 'Illustration of calculator resting on top of money'}
# {'src': '/home/feature/2022-12-06-how-the-covid-19-pandemic-changed-urban-and-rural-spending-habits.png', 'alt': 'Virus diagram with dollar sign with urban area background'}
# {'src': '/home/feature/2022-11-14-exploring-price-increases-in-2021-and-previous-periods-of-inflation.png', 'alt': 'Chart illustration with spending categories.'}
# {'src': '/home/feature/2022-11-07-workplace-injuries-and-job-requirements-for-construction-laborers.png', 'alt': 'Two construction laborers working on a scaffold'}
# {'src': '/home/feature/2022-11-01-improving-estimates-of-hours-worked-for-us-productivity-measurement.png', 'alt': 'Graphic with gears and clocks'}
# {'src': '/images/layout/rss.gif', 'alt': 'RSS'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/icon_new_release_small.gif', 'alt': 'News Release'}
# {'src': '/images/layout/historical_icon.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/explainers_historical_data.gif', 'alt': 'Historical Data'}
# {'src': '/images/icons/explainers_news_release.gif', 'alt': 'News Release'}
# {'src': '/images/icons/facebook.png', 'alt': 'share on facebook'}
# {'src': '/images/icons/twitter.png', 'alt': 'share on twitter'}
# {'src': '/images/icons/linkedin.png', 'alt': 'share on linkedin'}
# {'src': '/images/bls_emblem_trans.png', 'alt': 'U.S. Bureau of Labor Statistics Logo '}

# %%
import requests
from bs4 import BeautifulSoup


# Making a GET request
r = requests.get('https://www.bls.gov/')

# Parsing the HTML
soup = BeautifulSoup(r.content, 'html.parser')

# find all the anchor tags with "href"
for link in soup.find_all('a'):
	print(link.get('href'))
# Out:
# #startcontent
# https://www.dol.gov/
# https://www.bls.gov/
# http://twitter.com/BLS_gov
# http://twitter.com/BLS_gov
# /schedule/news_release/
# https://blogs.bls.gov/blog/
# https://www.bls.gov/
# /bls/infohome.htm
# /bls/history/home.htm
# /bls/senior_staff/home.htm
# /bls/bls_budget_and_performance.htm
# /bls/faqs.htm
# /bls/topicsaz.htm
# /bls/glossary.htm
# /jobs/
# /bls/bls-speakers/
# /errata/
# /bls/contact.htm
# /bls/overview.htm
# /bls/demographics.htm
# /bls/industry.htm
# /bls/business.htm
# /bls/occupation.htm
# /bls/geography.htm
# /audience/
# /audience/business.htm
# /audience/consumers.htm
# /audience/developers.htm
# /audience/economists.htm
# /audience/investors.htm
# /audience/jobseekers.htm
# /audience/media.htm
# /audience/policy.htm
# /audience/researcher.htm
# /audience/students.htm
# /respondents/
# /bls/proghome.htm
# /bls/inflation.htm
# /cpi/
# /ppi/
# /mxp/
# /bls/escalation.htm
# /pir/
# /bls/wages.htm
# /ncs/ect/
# /ncs/
# /oes/
# /cps/earnings.htm#demographics
# /ces/
# https://www.bls.gov/cew/
# /ncs/ebs/
# /mwe/
# /crp/
# /wsp/
# /ors/
# /bls/unemployment.htm
# /cps/
# /lau/
# /ers/
# /bls/employment.htm
# /ces/
# /sae/
# https://www.bls.gov/cew/
# /cps/
# /air/
# /emp/
# /jlt/
# /brs/
# /oes/
# /nls/
# /bdm/
# /fdi/
# /ers/
# /iif/
# /bls/productivity.htm
# /productivity/
# /dpr/
# /bls/spending.htm
# /cex/
# /tus/
# /bls/international.htm
# /itc/
# /mxp/
# /regions/
# /regions/new-england/
# /regions/new-york-new-jersey/
# /regions/mid-atlantic/
# /regions/southeast/
# /regions/midwest/
# /regions/southwest/
# /regions/mountain-plains/
# /regions/west/
# /data/
# /data/tools.htm
# https://data.bls.gov/cgi-bin/surveymost?bls
# https://data.bls.gov/cgi-bin/srgate
# /data/home.htm
# https://beta.bls.gov/dataQuery/search
# /developers/home.htm
# /data/apps.htm
# /charts/home.htm
# /data/inflation_calculator.htm
# https://data.bls.gov/iirc/
# https://data.bls.gov/apps/compensation-comparison-matrix/home.htm
# https://data.bls.gov/apps/demographic-comparison-matrix/home.htm
# https://data.bls.gov/apps/covid-dashboard/home.htm
# https://data.bls.gov/apps/industry-productivity-viewer/home.htm
# https://data.bls.gov/cew/apps/data_views/data_views.htm#tab=Tables
# https://data.bls.gov/cew/apps/bls_naics/bls_naics_app.htm
# /data/tables.htm
# /eag/eag.us.htm
# /eag/home.htm
# /iag/home.htm
# https://download.bls.gov/pub/time.series/
# /data/#historical-tables
# /bls/moredata.htm
# /rda/home.htm
# /data/archived.htm
# /help/hlpform1.htm
# /help/notice.htm
# /opub/
# /opub/
# /opub/ted/
# /opub/mlr/
# /opub/btn/
# /spotlight/
# /opub/reports
# https://blogs.bls.gov/blog/
# /video/
# /careeroutlook/
# /ooh/
# /opub/geographic-profile/
# /opub/hom/
# /osmr/research-papers/
# /opub/copyright-information.htm
# /opub/opbinfo.htm
# /opub/update.htm
# /bls/newsrels.htm
# /bls/newsrels.htm#latest-releases
# /bls/newsrels.htm#major
# /schedule/news_release/
# /schedule/
# /schedule/schedule/by_prog/all_sched.htm
# /schedule/news_release/current_year.asp
# /bls/archived_sched.htm
# /bls/news-release/
# /bls/newsrels.htm#OEUS
# /bls/newsrels.htm#OEUS
# /bls/newsrels.htm#OEUS
# /bls/newsrels.htm#OPLC
# /bls/newsrels.htm#OCWC
# /bls/newsrels.htm#OPT
# /bls/newsrels.htm#OEP
# /bls/newsrels.htm#NEWS
# /k12/
# /k12/
# /k12/games/
# /k12/students/
# /k12/teachers/
# /k12/faq.htm
# https://beta.bls.gov
# https://beta.bls.gov/labs/?p=600
# /news.release/ximpim.nr0.htm
# /news.release/ximpim.nr0.htm
# /news.release/pdf/ximpim.pdf
# /feed/ximpim.rss
# /charts/import-export/
# /news.release/cpi.nr0.htm
# /news.release/realer.nr0.htm
# /news.release/ppi.nr0.htm
# /news.release/work.nr0.htm
# /bls/newsrels.htm
# #newengland
# #newyork-newjersey
# #mid-atlantic
# #southeast
# #midwest
# #southwest
# #mountain-plains
# #west
# /regions/new-england/
# /regions/new-york-new-jersey/
# /regions/mid-atlantic/
# /regions/southeast/
# /regions/midwest/
# /regions/southwest/
# /regions/mountain-plains/
# /regions/west/
# /regions/home.htm
# /charts/
# /ooh/
# /ooh/
# https://www.bls.gov/spotlight/
# https://www.bls.gov/spotlight/2022/inflation-experiences-for-lower-and-higher-income-households/home.htm
# https://www.bls.gov/spotlight/2022/inflation-experiences-for-lower-and-higher-income-households/home.htm
# https://www.bls.gov/spotlight/2022/inflation-experiences-for-lower-and-higher-income-households/home.htm
# https://www.bls.gov/spotlight/
# https://www.bls.gov/spotlight/2022/how-the-covid-19-pandemic-changed-urban-and-rural-spending-habits/home.htm
# https://www.bls.gov/spotlight/2022/how-the-covid-19-pandemic-changed-urban-and-rural-spending-habits/home.htm
# https://www.bls.gov/spotlight/2022/how-the-covid-19-pandemic-changed-urban-and-rural-spending-habits/home.htm
# https://www.bls.gov/opub/btn/
# https://www.bls.gov/opub/btn/volume-11/exploring-price-increases-in-2021-and-previous-periods-of-inflation.htm
# https://www.bls.gov/opub/btn/volume-11/exploring-price-increases-in-2021-and-previous-periods-of-inflation.htm
# https://www.bls.gov/opub/btn/volume-11/exploring-price-increases-in-2021-and-previous-periods-of-inflation.htm
# https://www.bls.gov/spotlight/
# https://www.bls.gov/spotlight/2022/workplace-injuries-and-job-requirements-for-construction-laborers/home.htm
# https://www.bls.gov/spotlight/2022/workplace-injuries-and-job-requirements-for-construction-laborers/home.htm
# https://www.bls.gov/spotlight/2022/workplace-injuries-and-job-requirements-for-construction-laborers/home.htm
# https://www.bls.gov/opub/mlr/
# https://www.bls.gov/opub/mlr/2022/article/improving-estimates-of-hours-worked-for-us-productivity-measurement.htm
# https://www.bls.gov/opub/mlr/2022/article/improving-estimates-of-hours-worked-for-us-productivity-measurement.htm
# https://www.bls.gov/opub/mlr/2022/article/improving-estimates-of-hours-worked-for-us-productivity-measurement.htm
# javascript:void(0);
# #
# #
# #
# #
# #
# javascript:void(0);
# /feed/bls_latest.rss
# /news.release/cpi.toc.htm
# /news.release/cpi.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=CUSR0000SA0&output_view=pct_1mth
# /news.release/empsit.toc.htm
# /news.release/empsit.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=LNS14000000
# /news.release/empsit.toc.htm
# /news.release/empsit.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=CES0000000001&output_view=net_1mth
# /news.release/empsit.toc.htm
# /news.release/empsit.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=CES0500000003&output_view=net_1mth
# /news.release/ppi.toc.htm
# /news.release/ppi.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=WPSFD4&output_view=pct_1mth
# /news.release/eci.toc.htm
# /news.release/eci.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=CIS1010000000000Q
# /news.release/prod2.toc.htm
# /news.release/prod2.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=PRS85006092
# /news.release/ximpim.toc.htm
# /news.release/ximpim.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=EIUIR&output_view=pct_1mth
# /news.release/ximpim.toc.htm
# /news.release/ximpim.toc.htm
# /pdq/SurveyOutputServlet?data_tool=latest_numbers&series_id=EIUIQ&output_view=pct_1mth
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# https://www.bls.gov/
# /bls/proghome.htm
# /data/
# /opub/
# /bls/newsrels.htm
# /k12/
# https://beta.bls.gov
# tel:12026915200
# tel:711
# /home.htm
# https://data.bls.gov/forms/opb.htm?/home.htm
# #quicklinksli5
# https://www.oig.dol.gov/
# /bls/bls_budget_and_performance.htm
# https://www.dol.gov/grants
# /bls/no_fear_act.htm
# https://www.usa.gov/
# https://www.vote.gov/
# #quicklinksli6
# /bls/sitemap.htm
# /bls/blsfoia.htm
# /bls/pss.htm
# /bls/disclaimer.htm
# /bls/linksite.htm
# /bls/website-policies.htm
# /help/
# http://twitter.com/BLS_gov
# https://www.youtube.com/channel/UCijn3WBpHtx4AvSya7NER9Q
# javascript:window.open('https://public.govdelivery.com/accounts/USDOLBLS/subscriber/new ','Popup','width=800,height=500,toolbar=no,scrollbars=yes,resizable=yes'); void('');
